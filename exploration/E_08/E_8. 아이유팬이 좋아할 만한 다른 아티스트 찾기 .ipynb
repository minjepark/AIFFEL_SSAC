# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터: `wget http://mtg.upf.edu/static/datasets/last.fm/lastfm-dataset-360K.tar.gz`

# %% [markdown]
# ## 8-3. 데이터 탐색하기와 전처리
#
# ### 데이터 전처리
#     + row data를 pd.read_csv(sep='\t')
#     + 필요없는 칼럼지우기 (artist_id = artist_name)
#     + artist이름 소문자로 변환
# ### 데이터 탐색
#     + .unique()를 찍어서 데이터 갯수 확인하기
#     + 결측치 처리 (여기서는 안하네...)
#
# #### tsv파일: `Tab-Separpted Values`의 약자로 구분자가 tab이다.

# %%
#불러오기 
import pandas as pd
import os

raw_data = os.getenv("HOME") + '/aiffel/recommendate_iu/data/lastfm-dataset-360k/usersha1-artmbid-artname-plays.tsv'
col_names=['user_id','artist_id','artist_name','play']
data= pd.read_csv(raw_data,names=col_names,sep = '\t')# sep='\t'로 주어야 tsv를 열 수 있습니다.  
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5dfffffd9ef2> in <module>
#       5 raw_data = os.getenv("HOME") + '/aiffel/recommendate_iu/data/lastfm-dataset-360k/usersha1-artmbid-artname-plays.tsv'
#       6 col_names=['user_id','artist_id','artist_name','play']
# ----> 7 data= pd.read_csv(raw_data,columns=col_names,sep = '\t')# sep='\t'로 주어야 tsv를 열 수 있습니다.
#       8 data.head(10)
#
# TypeError: read_csv() got an unexpected keyword argument 'columns'

# %%
using_cols = ['user_id','artist','play'] #artist id는 불필요한 데이터 
data = data[using_cols]
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c89a35b5c6f1> in <module>
#       1 using_cols = ['user_id','artist','play'] #artist id는 불필요한 데이터
# ----> 2 data = data[using_cols]
#       3 data.head()
#
# NameError: name 'data' is not defined
