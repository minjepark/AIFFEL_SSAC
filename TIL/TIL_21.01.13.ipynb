# %% [markdown]
# 1) root계정이란?
#
# 2)패키지와 라이브러리의 차이
#
# 3)--reinstall install은 패키지가 문제 있을 때 재설치를 위한 명령어인데 이렇게 하면 컴퓨터 해당 폴더에 있는 패키지를 모두 재설치 하나요??
#
# 4)`upgrade`명령어는 `sudo apt-get upgrade 패키지` 이렇게 패키지를 넣어줘야 하는 거죠? 안그러면 설치된 모든 패키지를 업그레이드 시키는 거죠?
#
# 5)패키지의 의존성을 검사한다는게 무슨 말일까요?
#
# 6)source파일만 다운 받았다는 건 무슨 말인가요?
#
# 7)`sudo apt-cache search 패키지명`일 경우에 패키지 명을 검색한다고 하는데 이렇게 패키지명을 입력한다면 패키지명은 알고 있는거라 쫌 이상합니다.
#
# 8)`sudo apt-get clearn`이 패키지 설치를 위해 다운받은 데이터를 삭제하는 명령어라고 해서 써보니깐 된다. 그리고 다시 `apt-get clean` 남아 있는데 왜그럴까요?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 9) 나의 주피터 노트북에서는 다른 이미지인데 왜 깃헙에 올리니깐 동일한 이미지로 출력이 되는 걸까요?
