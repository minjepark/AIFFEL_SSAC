# %% [markdown]
# github 원격저장소에 있는 디렉토리 지우기
#
# `수정사항을 모두 올리고 진행해야 합니다.`
# `git add .`
#
# `git rm -r test`: 원격저장소에 있는 디렉토리 지우기 거를 지울 수 있음
# `git commit -m 'rm':
# `git push`
#
# ![image.png](attachment:image.png)
#
# `git log` : 커밋한 내역이 나옵니다.
# 'git reset 최신순으로 나타난 파일 --hard`

# %%
class Modulabs:
    풀잎스쿨 = True
    랩 = True

# %%
from sklearn.linear_model import
